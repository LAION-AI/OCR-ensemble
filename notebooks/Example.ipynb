# %%
import sys
sys.path.append("..")
from ocr_ensemble.data import load_dataset_1K
from matplotlib import pyplot as plt

# %%
dataset = load_dataset_1K()
# Out:
# downloading dataset...
# Starting the downloading of this file
# Sharding file number 1 of 1 called C:/Users/Chris Wendler/Documents/git/2023/OCR-ensemble/data/laion2b-en-1K.parquet
# 0it [00:00, ?it/s]
# File sharded in 11 shards
# Downloading starting now, check your bandwidth speed (with bwm-ng)your cpu (with htop), and your disk usage (with iotop)!
# 11it [00:34,  3.16s/it]

# %%
for el in dataset:
    img, txt = el
    plt.imshow(img)
    plt.show()
    break

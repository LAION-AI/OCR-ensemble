# %%
import sys
sys.path.append("..")
from ocr_ensemble.data import load_dataset_1K, load_dataset_10K
from matplotlib import pyplot as plt
import paddleocr
import random
from tqdm import tqdm
import numpy as np
import pandas as pd

# %%
dataset = load_dataset_10K()
reader = paddleocr.PaddleOCR(lang='en')
# Out:
# [2023/04/25 19:35:02] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Chris Wendler/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Chris Wendler/.paddleocr/whl\\rec\\en\\en_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='C:\\anaconda\\envs\\py39\\lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='C:\\Users\\Chris Wendler/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, lang='en', det=True, rec=True, type='ocr', ocr_version='PP-OCRv3', structure_version='PP-StructureV2')

# %%
ocrs = []
labels = {}
for idx, el in enumerate(tqdm(dataset)):
    img, txt, key = el
    ocr = reader.ocr((255*img).astype(np.uint8), rec=False) 
    ocrs += [ocr]
    labels[key] = 1 if len(ocr[0]) > 0 else 0
# Out:
# 0it [00:00, ?it/s]
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 1it [00:00,  5.75it/s]
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 3it [00:00, 11.03it/s]
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 5it [00:00, 13.87it/s]
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8it [00:00, 16.43it/s]
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 10it [00:00, 15.21it/s]
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 13it [00:00, 17.64it/s]
# [2023/04/25 19:35:06] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 15it [00:00, 18.07it/s]
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 18it [00:01, 19.49it/s]
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 21it [00:01, 20.22it/s]
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 24it [00:01, 21.60it/s]
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 27it [00:01, 23.39it/s]
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 30it [00:01, 23.58it/s]
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 33it [00:01, 24.30it/s]
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 36it [00:01, 24.83it/s]
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:07] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 39it [00:01, 25.13it/s]
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 42it [00:02, 24.29it/s]
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 45it [00:02, 23.46it/s]
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 48it [00:02, 23.40it/s]
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 51it [00:02, 23.97it/s]
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 54it [00:02, 24.88it/s]
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 57it [00:02, 24.67it/s]
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 60it [00:02, 23.71it/s]
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 63it [00:02, 23.91it/s]
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 66it [00:03, 24.23it/s]
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 69it [00:03, 22.37it/s]
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 72it [00:03, 22.38it/s]
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 75it [00:03, 23.10it/s]
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 78it [00:03, 24.21it/s]
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 81it [00:03, 23.41it/s]
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 84it [00:03, 22.83it/s]
# [2023/04/25 19:35:09] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 87it [00:03, 22.39it/s]
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 90it [00:04, 21.76it/s]
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 93it [00:04, 22.33it/s]
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 96it [00:04, 22.55it/s]
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 99it [00:04, 22.15it/s]
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 102it [00:04, 22.62it/s]
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 105it [00:04, 22.06it/s]
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:10] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 108it [00:04, 20.73it/s]
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 111it [00:05, 22.14it/s]
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 114it [00:05, 21.54it/s]
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 117it [00:05, 21.56it/s]
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 120it [00:05, 22.59it/s]
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 123it [00:05, 23.76it/s]
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 126it [00:05, 23.55it/s]
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 129it [00:05, 24.20it/s]
# [2023/04/25 19:35:11] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 132it [00:05, 25.23it/s]
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 135it [00:06, 22.55it/s]
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 138it [00:06, 23.18it/s]
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 141it [00:06, 24.27it/s]
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 144it [00:06, 24.02it/s]
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 147it [00:06, 23.56it/s]
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 150it [00:06, 21.92it/s]
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:12] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 153it [00:06, 22.56it/s]
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 156it [00:07, 23.74it/s]
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 159it [00:07, 23.42it/s]
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 162it [00:07, 23.59it/s]
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 165it [00:07, 23.33it/s]
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 168it [00:07, 22.52it/s]
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 171it [00:07, 22.33it/s]
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 174it [00:07, 22.60it/s]
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:13] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 177it [00:07, 23.77it/s]
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 180it [00:08, 23.95it/s]
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 183it [00:08, 24.37it/s]
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 186it [00:08, 23.63it/s]
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 189it [00:08, 24.14it/s]
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 192it [00:08, 24.27it/s]
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 195it [00:08, 24.73it/s]
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 198it [00:08, 23.92it/s]
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:14] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 201it [00:08, 24.29it/s]
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 204it [00:09, 24.80it/s]
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 207it [00:09, 25.69it/s]
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 210it [00:09, 24.07it/s]
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 213it [00:09, 24.64it/s]
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 216it [00:09, 24.87it/s]
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 219it [00:09, 24.91it/s]
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 222it [00:09, 23.25it/s]
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:15] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 225it [00:09, 23.58it/s]
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 228it [00:10, 23.82it/s]
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 231it [00:10, 23.99it/s]
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 234it [00:10, 24.64it/s]
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 237it [00:10, 25.25it/s]
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 240it [00:10, 24.02it/s]
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 243it [00:10, 24.13it/s]
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 246it [00:10, 24.93it/s]
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 249it [00:10, 25.01it/s]
# [2023/04/25 19:35:16] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 252it [00:10, 25.59it/s]
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 255it [00:11, 23.55it/s]
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 258it [00:11, 23.14it/s]
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 261it [00:11, 23.55it/s]
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 264it [00:11, 23.69it/s]
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 267it [00:11, 23.78it/s]
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 270it [00:11, 24.07it/s]
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 273it [00:11, 24.34it/s]
# [2023/04/25 19:35:17] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 276it [00:11, 24.97it/s]
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 279it [00:12, 24.98it/s]
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 282it [00:12, 24.43it/s]
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 285it [00:12, 24.24it/s]
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 288it [00:12, 24.35it/s]
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 291it [00:12, 24.78it/s]
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 294it [00:12, 24.13it/s]
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:18] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 297it [00:12, 21.73it/s]
# [2023/04/25 19:35:19] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:19] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:19] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 300it [00:13, 21.97it/s]
# [2023/04/25 19:35:19] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:19] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:19] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 303it [00:13, 22.05it/s]
# [2023/04/25 19:35:19] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:35:19] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# ...
# [2023/04/25 19:40:46] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8155it [05:40, 23.33it/s]
# [2023/04/25 19:40:46] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:46] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:46] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8158it [05:40, 23.42it/s]
# [2023/04/25 19:40:46] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:46] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:46] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8161it [05:40, 24.16it/s]
# [2023/04/25 19:40:46] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:46] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:46] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8164it [05:40, 23.54it/s]
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8167it [05:41, 23.51it/s]
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8170it [05:41, 24.00it/s]
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8173it [05:41, 24.35it/s]
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8176it [05:41, 24.36it/s]
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8179it [05:41, 24.49it/s]
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8182it [05:41, 24.28it/s]
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8185it [05:41, 24.67it/s]
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8188it [05:41, 24.77it/s]
# [2023/04/25 19:40:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8191it [05:41, 25.34it/s]
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8194it [05:42, 26.03it/s]
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8197it [05:42, 25.71it/s]
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8200it [05:42, 24.31it/s]
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8203it [05:42, 24.40it/s]
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8206it [05:42, 24.04it/s]
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8209it [05:42, 24.56it/s]
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8212it [05:42, 24.45it/s]
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:48] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8215it [05:42, 24.61it/s]
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8218it [05:43, 24.36it/s]
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8221it [05:43, 24.20it/s]
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8224it [05:43, 23.96it/s]
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8227it [05:43, 23.86it/s]
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8230it [05:43, 24.43it/s]
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8233it [05:43, 24.18it/s]
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8236it [05:43, 24.12it/s]
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:49] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8239it [05:43, 23.91it/s]
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8242it [05:44, 24.29it/s]
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8245it [05:44, 24.38it/s]
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8248it [05:44, 24.87it/s]
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8251it [05:44, 24.97it/s]
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8254it [05:44, 23.68it/s]
# [2023/04/25 19:40:50] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# 8255it [05:44, 23.96it/s]

# %%
len(labels)
# Out:
# 8255

# %%
sum(list(labels.values()))
# Out:
# 4931

# %%
import json

with open('../data/laion2b-en-10K-labels.json', 'w') as f:
    json.dump(labels, f)

# %% [markdown]
# # train a small classifier

# %%
import clip
import torch
import torchvision.transforms as T
from PIL import Image
from einops import rearrange
import json
from functools import partial

def identity(x):
    return x

with open('../data/laion2b-en-10K/labels.json', 'r') as f:
    labels = json.load(f)

def key2label(key, labels):
    return labels[key]

device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)
transform = T.ToPILImage()

img = next(iter(dataset))


clip_preproc = T.Lambda(lambda img: preprocess(transform(rearrange(torch.tensor(img), 'a b c -> c a b'))))

dataset2 = dataset.map_tuple(clip_preproc, identity, partial(key2label, labels=labels))

# %%
loader = torch.utils.data.DataLoader(dataset2, batch_size=50)

# %%
features = []
targets = []
for imgs, captions, labels in tqdm(loader):
    feats = model.encode_image(imgs.to(device))
    features += [feats.cpu().detach()]
    targets += [labels.detach()]
# Out:
# 166it [02:00,  1.38it/s]

# %%
features = torch.cat(features, axis=0)
targets = torch.cat(targets, axis=0)

# %%
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
cv = LogisticRegressionCV(Cs=[0.001, 0.01, 0.1, 10, 100, 1000], refit=True)
cv.fit(features, targets)
# Out:
# LogisticRegressionCV(Cs=[0.001, 0.01, 0.1, 10, 100, 1000])

# %%
cv.scores_
# Out:
# {1: array([[0.76983646, 0.79890975, 0.79527559, 0.78982435, 0.78921866,
#          0.78921866],
#         [0.75772259, 0.79224712, 0.79588128, 0.78376741, 0.78316172,
#          0.78255603],
#         [0.75590551, 0.78921866, 0.79285282, 0.7849788 , 0.78376741,
#          0.78195033],
#         [0.7662023 , 0.78982435, 0.79769836, 0.79890975, 0.7940642 ,
#          0.79588128],
#         [0.77710478, 0.80860085, 0.79951545, 0.79224712, 0.79345851,
#          0.7940642 ]])}

# %%
n_train = int(0.8*len(features))
X_train = features[:n_train]
y_train = targets[:n_train]
X_test = features[n_train:]
y_test = targets[n_train:]
clf = LogisticRegression(C=10)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10)

# %%
confusion_matrix(y_test, clf.predict(X_test))
# Out:
# array([[437, 125],
#        [208, 881]], dtype=int64)
